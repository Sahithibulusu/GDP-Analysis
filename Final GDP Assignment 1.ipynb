# %%
import pandas as pd
import numpy as np

# %%
#remove rows for 2016-17
df=pd.read_csv("State-wise Gross Domestic Product (GDP) at current price on yearly basis.csv") 
df_del_16_17=df.loc[df.Duration!='2016-17'] #removing 2016-17 data from dataset
df_del_16_17
# Out:
#                    Items  Description Duration  Andhra Pradesh   \
# 0  GSDP - CURRENT PRICES (` in Crore)  2011-12        379402.00
# 1  GSDP - CURRENT PRICES (` in Crore)  2012-13        411404.00
# 2  GSDP - CURRENT PRICES (` in Crore)  2013-14        464272.00
# 3  GSDP - CURRENT PRICES (` in Crore)  2014-15        526468.00
# 4  GSDP - CURRENT PRICES (` in Crore)  2015-16        609934.00
# 6       (% Growth over previous year)  2012-13             8.43
# 7       (% Growth over previous year)  2013-14            12.85
# 8       (% Growth over previous year)  2014-15            13.40
# 9       (% Growth over previous year)  2015-16            15.85
#
#    Arunachal Pradesh      Assam      Bihar  Chhattisgarh       Goa    Gujarat  \
# 0           11063.00  143175.00  247144.00     158074.00  42367.00  615606.00
# 1           12547.00  156864.00  282368.00     177511.00  38120.00  724495.00
# 2           14602.00  177745.00  317101.00     206690.00  35921.00  807623.00
# ...

# %%
#average growth of states for the duration 2013-14, 2014-15 and 2015-16 
avg_grwth_of_states=df_del_16_17.loc[(df['Items  Description'] == "(% Growth over previous year)") & (df.Duration!='2012-13')].mean(axis=0)
print(avg_grwth_of_states)
# Out:
# Andhra Pradesh               14.033333
# Arunachal Pradesh            14.413333
# Assam                        12.650000
# Bihar                        13.603333
# Chhattisgarh                 13.703333
# Goa                           6.033333
# Gujarat                      11.126667
# Haryana                      11.846667
# Himachal Pradesh             12.280000
# Jammu & Kashmir              10.900000
# Jharkhand                    11.500000
# Karnataka                    14.120000
# Kerala                       12.583333
# Madhya Pradesh               12.626667
# Maharashtra                  11.260000
# Manipur                      14.610000
# Meghalaya                     6.953333
# Mizoram                      17.700000
# Nagaland                     16.415000
# Odisha                        9.836667
# Punjab                       11.185000
# Rajasthan                    11.320000
# Sikkim                       10.486667
# Tamil Nadu                   12.336667
# ...

# %%
#plot for the mean of % Growth over previous year
import matplotlib.pyplot as plt
plt.figure(figsize=(15,5))
avg_grwth_of_states.sort_values().plot(kind='bar')
plt.ylabel('Average Growth Rate')
plt.xlabel('States')
plt.title('mean of % Growth over previous year')
plt.show()

# %% [markdown]
# ###Report
#
# The fast growing states are Mizoram,Tripura,Nagaland,Manipur,Arunachal Pradesh
#
# The struggling states are Goa, Meghalaya,odisha, sikkim, Jammu & Kashmir

# %%
#curiousity Exercise - Average growth of my state Andhra Pradesh for the period 2013-16

avg_grwth_of_states['Telangana']/avg_grwth_of_states['All_India GDP']
# Out:
# 1.1392442725379353

# %% [markdown]
# My state Telangana growth rate is 1.13% more than nation growth rate

# %%
totalGDP_15_16=df.loc[(df['Items  Description']=='GSDP - CURRENT PRICES (` in Crore)') & (df['Duration']=='2015-16')]
totalGDP_15_16['States'] = totalGDP_15_16['Items  Description'] + '_'+ totalGDP_15_16['Duration']
totalGDP_15_16.set_index('States', inplace = True)
totalGDP_15_16=totalGDP_15_16.drop(['Items  Description'], axis=1)
totalGDP_15_16=totalGDP_15_16.drop(['Duration'], axis=1)

totalGDP_15_16=totalGDP_15_16.drop(['All_India GDP'], axis=1)
totalGDP_15_16=totalGDP_15_16.transpose()
totalGDP_15_16.sort_values(by=['GSDP - CURRENT PRICES (` in Crore)_2015-16'],inplace=True)
totalGDP_15_16
# Out:
# C:\Users\mutnoory_souravi\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# States                     GSDP - CURRENT PRICES (` in Crore)_2015-16
# Sikkim                                                        16637.0
# Arunachal Pradesh                                             18784.0
# Puducherry                                                    26533.0
# Meghalaya                                                     26745.0
# Chandigarh                                                    30304.0
# Goa                                                           45002.0
# ...

# %%
totalGDP_15_16=totalGDP_15_16[totalGDP_15_16.isnull().sum(axis=1)==0]

# %%
GSDP_15_16_bar = totalGDP_15_16[['GSDP - CURRENT PRICES (` in Crore)_2015-16']].plot(kind='bar', title ="State wise GSDP 2015-16",figsize=(15, 5), legend=True, fontsize=12)

# %% [markdown]
# Top 5 states based on total GDP TamilNadu, Uttar Pradesh, Karnataka, Gujarat, Andhra Pradesh bottom 5 states based on total GDP Sikkim, Arunachal Pradesh, Puducherry, Meghalaya, Chandigarh

# %%
import glob, os
path = r'C:\Users\mutnoory_souravi\Downloads\gdp assignment' #path
all_files = glob.glob(path +"/*.csv") 
li =[]
for filename in all_files:
    df=pd.read_csv(filename, index_col=None, header=0,encoding='unicode_escape')
    df=df[['S.No.','Item','2014-15']] #selecting required columns
    #df #transpose
    #new_header = df.iloc[0] #assigning header
    #df=df[1:]#data from 1st row
    #df.columns = new_header#assigning new header
    df['State']=filename.split('\\')[-1].split('-')[1]#splitting and selecting required filename
    li.append(df)#appending the data to empty list

# %%
frame=pd.concat(li,axis=0,ignore_index=True,sort=False) #concatinating all the files

# %%
frame
# Out:
#      S.No.                                               Item      2014-15  \
# 0        1                  Agriculture, forestry and fishing   14819416.0
# 1      1.1                                              Crops    7893514.0
# 2      1.2                                          Livestock    4309078.0
# 3      1.3                               Forestry and logging     346160.0
# 4      1.4                            Fishing and aquaculture    2270664.0
# 5        2                               Mining and quarrying    1484300.0
# 6    Total                                            Primary   16303716.0
# 7        3                                      Manufacturing    4672266.0
# 8        4  Electricity, gas, water supply & other utility...    1151729.0
# 9        5                                       Construction    4664889.0
# 10   Total                                          Secondary   10488884.0
# ...

# %%
frame1=frame.drop(frame.loc[(frame['State']=='Puducherry')].index) #dropping puducherry Union Territory

# %%
frame1
# Out:
#      S.No.                                               Item      2014-15  \
# 0        1                  Agriculture, forestry and fishing   14819416.0
# 1      1.1                                              Crops    7893514.0
# 2      1.2                                          Livestock    4309078.0
# 3      1.3                               Forestry and logging     346160.0
# 4      1.4                            Fishing and aquaculture    2270664.0
# 5        2                               Mining and quarrying    1484300.0
# 6    Total                                            Primary   16303716.0
# 7        3                                      Manufacturing    4672266.0
# 8        4  Electricity, gas, water supply & other utility...    1151729.0
# 9        5                                       Construction    4664889.0
# 10   Total                                          Secondary   10488884.0
# ...

# %%
frame2=frame1.drop(frame1.loc[(frame['State']=='Delhi')].index)#dropping Delhi Union Territory

# %%
frame2
# Out:
#      S.No.                                               Item      2014-15  \
# 0        1                  Agriculture, forestry and fishing   14819416.0
# 1      1.1                                              Crops    7893514.0
# 2      1.2                                          Livestock    4309078.0
# 3      1.3                               Forestry and logging     346160.0
# 4      1.4                            Fishing and aquaculture    2270664.0
# 5        2                               Mining and quarrying    1484300.0
# 6    Total                                            Primary   16303716.0
# 7        3                                      Manufacturing    4672266.0
# 8        4  Electricity, gas, water supply & other utility...    1151729.0
# 9        5                                       Construction    4664889.0
# 10   Total                                          Secondary   10488884.0
# ...

# %%
df_all_states=frame2.drop(frame2.loc[(frame['State']=='Chandigarh')].index)#dropping Chandigarh Union Territory

# %%
df_all_states#final data frame without union territories
# Out:
#      S.No.                                               Item      2014-15  \
# 0        1                  Agriculture, forestry and fishing   14819416.0
# 1      1.1                                              Crops    7893514.0
# 2      1.2                                          Livestock    4309078.0
# 3      1.3                               Forestry and logging     346160.0
# 4      1.4                            Fishing and aquaculture    2270664.0
# 5        2                               Mining and quarrying    1484300.0
# 6    Total                                            Primary   16303716.0
# 7        3                                      Manufacturing    4672266.0
# 8        4  Electricity, gas, water supply & other utility...    1151729.0
# 9        5                                       Construction    4664889.0
# 10   Total                                          Secondary   10488884.0
# ...

# %%
#Graph for Per Capita GSDP (Rs.) for states
plt.figure(figsize=(15,5))
df_all_states.loc[(df_all_states['Item']=='Per Capita GSDP (Rs.)')].iloc[:,1:].sort_values(by='2014-15').set_index('State').iloc[:,-1].plot(kind='bar')
#plt.title('Per Capita GSDP (Rs.)')
plt.xlabel('States')
plt.ylabel('Per Capita GSDP (Rs.)')
plt.show()

# %% [markdown]
# As per the above graph, the bottom 5 states in Per Capita GSDP are Bihar, Uttar Pradesh, Manipur, Assam, Jharkhand The top 5 states ate Goa, Sikkim, Haryana, Kerala, Uttarakhand

# %%
#Ratio of highest percapita GDP to the lowest percapita GDP
# state with highest percapita is Goa
df_all_states.loc[(df_all_states.State == "Goa")&(df_all_states['Item'] == "Per Capita GSDP (Rs.)")].iloc[:,-2]
# Out:
# 263    271793.0
# Name: 2014-15, dtype: float64

# %%
#State with lowest percapita is Bihar 
df_all_states.loc[(df_all_states.State == "Bihar")&(df_all_states['Item'] == "Per Capita GSDP (Rs.)")].iloc[:,-2]
# Out:
# 131    33954.0
# Name: 2014-15, dtype: float64

# %%
271793.0/33954.0
# Out:
# 8.004741709371503

# %% [markdown]
# 8.004741709371503 is the ratio of highest to lowest percapita GSDP

# %%
#Percentage Contribution of Primary, Secondary and teritiary Sectors as a percentage of total GDP of all states

df_total_GDP=df_all_states.loc[(df_all_states['Item']=='Gross State Domestic Product')][['2014-15','State']] #selecting required columns

# %%
df_total_GDP.head()
# Out:
#         2014-15              State
# 30   52646842.0     Andhra_Pradesh
# 63    1676119.0  Arunachal_Pradesh
# 96   19809800.0              Assam
# 129  37391988.0              Bihar
# 195  23498180.0       Chhattisgarh

# %%
df_prim=df_all_states.loc[(df_all_states['Item']=='Primary')][['2014-15','State']].rename(columns={'2014-15':'Primary'}) #selecting primary and renaming the corresponding primary rows to primary

# %%
df_sec=df_all_states.loc[(df_all_states['Item']=='Secondary')][['2014-15','State']].rename(columns={'2014-15':'Secondary'}) #selecting Secondary and renaming the corresponding Secondary rows to Secondary

# %%
df_ter=df_all_states.loc[(df_all_states['Item']=='Tertiary')][['2014-15','State']].rename(columns={'2014-15':'Tertiary'}) #selecting Tertiary and renaming the corresponding Tertiary rows to Tertiary

# %%
#Merging df_prim,df_sec,df_ter
df_prim_sec=pd.merge(df_prim,df_sec,how='inner',on='State')#merging primary and secondary
df_prim_sec_ter=pd.merge(df_prim_sec,df_ter,how='inner',on='State')#merging o/p of primary and secondary to teritiary

# %%
df_prim_sec_ter.head()
# Out:
#       Primary              State   Secondary    Tertiary
# 0  16303716.0     Andhra_Pradesh  10488884.0  22032942.0
# 1    716959.0  Arunachal_Pradesh    287489.0    631844.0
# 2   5326697.0              Assam   4033091.0   9307109.0
# 3   8019997.0              Bihar   5984896.0  22179969.0
# 4   6400817.0       Chhattisgarh   8238886.0   7588778.0

# %%
#merging the above o/p to total gdp
df_gdp_prim_sec_ter=pd.merge(df_total_GDP,df_prim_sec_ter,how='inner',on='State')

# %%
df_gdp_prim_sec_ter.head()
# Out:
#       2014-15              State     Primary   Secondary    Tertiary
# 0  52646842.0     Andhra_Pradesh  16303716.0  10488884.0  22032942.0
# 1   1676119.0  Arunachal_Pradesh    716959.0    287489.0    631844.0
# 2  19809800.0              Assam   5326697.0   4033091.0   9307109.0
# 3  37391988.0              Bihar   8019997.0   5984896.0  22179969.0
# 4  23498180.0       Chhattisgarh   6400817.0   8238886.0   7588778.0

# %%
#percentage calculation of primary secondary and teritiary
df_gdp_prim_sec_ter['%primary_contribution']=(df_gdp_prim_sec_ter['Primary']/df_gdp_prim_sec_ter['2014-15'])*100#creating new column for Primary % calculation
df_gdp_prim_sec_ter['%secondary_contribution']=(df_gdp_prim_sec_ter['Secondary']/df_gdp_prim_sec_ter['2014-15'])*100#creating new column for Secondary % calculation
df_gdp_prim_sec_ter['%teritiary_contribution']=(df_gdp_prim_sec_ter['Tertiary']/df_gdp_prim_sec_ter['2014-15'])*100#creating new column forTertiary % calculation

# %%
#creating new column for % calculation in all sectors
df_gdp_prim_sec_ter['%Total_pri_sec_ter']=df_gdp_prim_sec_ter['%primary_contribution']+df_gdp_prim_sec_ter['%secondary_contribution']+df_gdp_prim_sec_ter['%teritiary_contribution']

# %%
df_gdp_prim_sec_ter=df_gdp_prim_sec_ter.sort_values(by='%Total_pri_sec_ter',ascending=False)#sorting values

# %%
df_gdp_prim_sec_ter.head()
# Out:
#       2014-15              State   Primary  Secondary   Tertiary  \
# 17  1841424.0           Nagaland  616178.0   212361.0   992956.0
# 14  1804276.0            Manipur  383140.0   220173.0  1177334.0
# 24  2966662.0            Tripura  942216.0   484393.0  1484709.0
# 16  1155933.0            Mizoram  225598.0   270072.0   637619.0
# 1   1676119.0  Arunachal_Pradesh  716959.0   287489.0   631844.0
#
#     %primary_contribution  %secondary_contribution  %teritiary_contribution  \
# 17              33.462038                11.532434                53.923268
# 14              21.235110                12.202845                65.252434
# 24              31.760140                16.327880                50.046450
# 16              19.516529                23.363984                55.160550
# 1               42.774946                17.152064                37.696846
#
#     %Total_pri_sec_ter
# 17           98.917740
# 14           98.690389
# 24           98.134469
# ...

# %%
#plotting stack-bar for % contribution of primary, secondary and teritiary sectors

df_gdp_prim_sec_ter.plot(kind='bar',x='State',y=['%primary_contribution','%secondary_contribution','%teritiary_contribution'],stacked=True)
plt.show()

# %%
#Selecting required columns and sorting 
states_per_capita=df_all_states.loc[df_all_states['Item']=='Per Capita GSDP (Rs.)'].sort_values(by='2014-15')[['2014-15','State']].rename(columns={'2014-15':'Per Capita GSDP (Rs.)'})
states_per_capita
# Out:
#      Per Capita GSDP (Rs.)              State
# 131                33954.0              Bihar
# 989                49450.0      Uttar_Pradesh
# 560                58442.0            Manipur
# 98                 60621.0              Assam
# 395                62091.0          Jharkhand
# 494                62989.0     Madhya_Pradesh
# 692                73979.0             Odisha
# 593                76228.0          Meghalaya
# 923                77358.0            Tripura
# 791                84837.0          Rajasthan
# 197                86860.0       Chhattisgarh
# 659                89607.0           Nagaland
# 626                97687.0            Mizoram
# 32                104977.0     Andhra_Pradesh
# 65                112718.0  Arunachal_Pradesh
# 758               126606.0             Punjab
# 890               139035.0          Telangana
# 296               141263.0            Gujarat
# 428               145141.0          Karnataka
# ...

# %%
q1 = round(27*0.20)#as the number of states ate 27
q2 = round(27*0.5)
q3 = round(27*0.85)
q4 = round(27*1)

# %%
c4 = states_per_capita.iloc[:q1,:]
c3 = states_per_capita.iloc[q1:q2,:]
c2 = states_per_capita.iloc[q2:q3,:]
c1 = states_per_capita.iloc[q3:q4,:]

# %%
c1 #States with 85-100 percentile
# Out:
#      Per Capita GSDP (Rs.)    State
# 461               154778.0   Kerala
# 329               164077.0  Haryana
# 824               240274.0   Sikkim
# 263               271793.0      Goa

# %%
c2 #States with 50-85 percentile
# Out:
#      Per Capita GSDP (Rs.)              State
# 65                112718.0  Arunachal_Pradesh
# 758               126606.0             Punjab
# 890               139035.0          Telangana
# 296               141263.0            Gujarat
# 428               145141.0          Karnataka
# 857               146503.0         Tamil_Nadu
# 362               147330.0   Himachal_Pradesh
# 527               152853.0        Maharashtra
# 956               153076.0        Uttarakhand

# %%
c3 #states with 20-50 percentile
# Out:
#      Per Capita GSDP (Rs.)           State
# 494                62989.0  Madhya_Pradesh
# 692                73979.0          Odisha
# 593                76228.0       Meghalaya
# 923                77358.0         Tripura
# 791                84837.0       Rajasthan
# 197                86860.0    Chhattisgarh
# 659                89607.0        Nagaland
# 626                97687.0         Mizoram
# 32                104977.0  Andhra_Pradesh

# %%
c4 #states with 0-20 percentile
# Out:
#      Per Capita GSDP (Rs.)          State
# 131                33954.0          Bihar
# 989                49450.0  Uttar_Pradesh
# 560                58442.0        Manipur
# 98                 60621.0          Assam
# 395                62091.0      Jharkhand

# %%
df_C1 = df_all_states.loc[df_all_states.State.isin(c1.State)&(df_all_states['S.No.']!='Total')&(~df_all_states['Item'].isin(['TOTAL GSVA at basic prices','Taxes on Products','Subsidies on products',"Population ('00)",'Per Capita GSDP (Rs.)']))] #details belongs to c1 states
df_C1 = df_C1[['Item','2014-15']].groupby(by='Item').sum().sort_values(by='2014-15',ascending=False).reset_index() #acquiring required columns
df_C1['%_of_GSDP_Contribution'] = df_C1['2014-15']/(df_C1['2014-15'][0])*100 #caclulating % of GSDP contribution
df_C1
# Out:
#                                                  Item      2014-15  \
# 0                        Gross State Domestic Product  101930677.0
# 1   Real estate, ownership of dwelling & professio...   14740245.0
# 2                   Agriculture, forestry and fishing   14391809.0
# 3               Trade, repair, hotels and restaurants   13995159.0
# 4                                       Manufacturing   13758793.0
# 5                                        Construction   11264451.0
# 6                                      Other services    8059922.0
# 7                                               Crops    7962514.0
# 8                            Trade & repair services*    7763847.0
# 9   Transport, storage, communication & services r...    6818560.0
# 10                            Trade & repair services    5225900.0
# 11                                          Livestock    4619756.0
# 12                                 Financial services    3936489.0
# ...

# %%
#calculationg the subsectors which are contributing 80% and above approximately
i=1;j=4
while df_C1.iloc[i:j,-1].sum()<=78:
    j=j+1

# %%
C1_Sub_Sectors= df_C1[['Item','%_of_GSDP_Contribution']].iloc[i:j].rename(columns={'Item':'C1_Sub_Sectors_contributingapprox80%'})

# %%
C1_Sub_Sectors
# Out:
#                 C1_Sub_Sectors_contributingapprox80%  %_of_GSDP_Contribution
# 1  Real estate, ownership of dwelling & professio...               14.461049
# 2                  Agriculture, forestry and fishing               14.119213
# 3              Trade, repair, hotels and restaurants               13.730076
# 4                                      Manufacturing               13.498187
# 5                                       Construction               11.051090
# 6                                     Other services                7.907258

# %%
#graph for the subsectors contributing approximately and more than 80%
plt.figure(figsize=(15,5))
C1_Sub_Sectors.set_index("C1_Sub_Sectors_contributingapprox80%").iloc[:-1,:]['%_of_GSDP_Contribution'].plot(kind='bar')
plt.xlabel("Subsectors(c1)")
plt.ylabel("%contribution")
plt.show()

# %%
df_C2 = df_all_states.loc[df_all_states.State.isin(c2.State)&(df_all_states['S.No.']!='Total')&(~df_all_states['Item'].isin(['TOTAL GSVA at basic prices','Taxes on Products','Subsidies on products',"Population ('00)",'Per Capita GSDP (Rs.)']))] #details belongs to c1 states
df_C2 = df_C2[['Item','2014-15']].groupby(by='Item').sum().sort_values(by='2014-15',ascending=False).reset_index() #acquiring required columns
df_C2['%_of_GSDP_Contribution'] = df_C2['2014-15']/(df_C2['2014-15'][0])*100 #caclulating % of GSDP contribution
df_C2
# Out:
#                                                  Item      2014-15  \
# 0                        Gross State Domestic Product  586380452.0
# 1                                       Manufacturing  109196530.0
# 2   Real estate, ownership of dwelling & professio...   92121446.0
# 3                   Agriculture, forestry and fishing   75209022.0
# 4               Trade, repair, hotels and restaurants   61238862.0
# 5                             Trade & repair services   55252334.0
# 6                                               Crops   47550095.0
# 7                                        Construction   40653562.0
# 8                                  Financial services   36296642.0
# 9                                      Other services   36253657.0
# 10  Transport, storage, communication & services r...   33749808.0
# 11                                          Livestock   19363891.0
# 12                              Public administration   18567815.0
# ...

# %%
#calculationg the subsectors which are contributing 80% and above approximately
i=1;j=4
while df_C2.iloc[i:j,-1].sum()<=78:
    j=j+1

# %%
C2_Sub_Sectors= df_C2[['Item','%_of_GSDP_Contribution']].iloc[i:j].rename(columns={'Item':'C2_Sub_Sectors_contributingapprox80%'})

# %%
C2_Sub_Sectors
# Out:
#                 C2_Sub_Sectors_contributingapprox80%  %_of_GSDP_Contribution
# 1                                      Manufacturing               18.622130
# 2  Real estate, ownership of dwelling & professio...               15.710184
# 3                  Agriculture, forestry and fishing               12.825977
# 4              Trade, repair, hotels and restaurants               10.443537
# 5                            Trade & repair services                9.422608
# 6                                              Crops                8.109086

# %%
#graph for the subsectors contributing approximately and more than 80%
plt.figure(figsize=(15,5))
C2_Sub_Sectors.set_index("C2_Sub_Sectors_contributingapprox80%").iloc[:-1,:]['%_of_GSDP_Contribution'].plot(kind='bar')
plt.xlabel("Subsectors(c2)")
plt.ylabel("%contribution")
plt.show()

# %%
df_C3 = df_all_states.loc[df_all_states.State.isin(c3.State)&(df_all_states['S.No.']!='Total')&(~df_all_states['Item'].isin(['TOTAL GSVA at basic prices','Taxes on Products','Subsidies on products',"Population ('00)",'Per Capita GSDP (Rs.)']))] #details belongs to c1 states
df_C3 = df_C3[['Item','2014-15']].groupby(by='Item').sum().sort_values(by='2014-15',ascending=False).reset_index() #acquiring required columns
df_C3['%_of_GSDP_Contribution'] = df_C3['2014-15']/(df_C3['2014-15'][0])*100 #caclulating % of GSDP contribution
df_C3
# Out:
#                                                  Item      2014-15  \
# 0                        Gross State Domestic Product  226164556.0
# 1                   Agriculture, forestry and fishing   58462535.0
# 2                                               Crops   36892330.0
# 3                                       Manufacturing   26407164.0
# 4               Trade, repair, hotels and restaurants   22602824.0
# 5                             Trade & repair services   21006974.0
# 6                                        Construction   20111072.0
# 7   Real estate, ownership of dwelling & professio...   18884241.0
# 8                                      Other services   15563222.0
# 9   Transport, storage, communication & services r...   15097286.0
# 10                                          Livestock   13068563.0
# 11                               Mining and quarrying   12454144.0
# 12                              Public administration   10424494.0
# ...

# %%
#calculationg the subsectors which are contributing 80% and above approximately
i=1;j=4
while df_C3.iloc[i:j,-1].sum()<=78:
    j=j+1

# %%
C3_Sub_Sectors= df_C3[['Item','%_of_GSDP_Contribution']].iloc[i:j].rename(columns={'Item':'C3_Sub_Sectors_contributingapprox80%'})

# %%
C3_Sub_Sectors
# Out:
#     C3_Sub_Sectors_contributingapprox80%  %_of_GSDP_Contribution
# 1      Agriculture, forestry and fishing               25.849557
# 2                                  Crops               16.312163
# 3                          Manufacturing               11.676084
# 4  Trade, repair, hotels and restaurants                9.993973
# 5                Trade & repair services                9.288358
# 6                           Construction                8.892230

# %%
#graph for the subsectors contributing approximately and more than 80%
plt.figure(figsize=(15,5))
C3_Sub_Sectors.set_index("C3_Sub_Sectors_contributingapprox80%").iloc[:-1,:]['%_of_GSDP_Contribution'].plot(kind='bar')
plt.xlabel("Subsectors(c3)")
plt.ylabel("%contribution")
plt.show()

# %%
df_C4 = df_all_states.loc[df_all_states.State.isin(c4.State)&(df_all_states['S.No.']!='Total')&(~df_all_states['Item'].isin(['TOTAL GSVA at basic prices','Taxes on Products','Subsidies on products',"Population ('00)",'Per Capita GSDP (Rs.)']))] #details belongs to c1 states
df_C4 = df_C3[['Item','2014-15']].groupby(by='Item').sum().sort_values(by='2014-15',ascending=False).reset_index() #acquiring required columns
df_C4['%_of_GSDP_Contribution'] = df_C4['2014-15']/(df_C4['2014-15'][0])*100 #caclulating % of GSDP contribution
df_C4
# Out:
#                                                  Item      2014-15  \
# 0                        Gross State Domestic Product  226164556.0
# 1                   Agriculture, forestry and fishing   58462535.0
# 2                                               Crops   36892330.0
# 3                                       Manufacturing   26407164.0
# 4               Trade, repair, hotels and restaurants   22602824.0
# 5                             Trade & repair services   21006974.0
# 6                                        Construction   20111072.0
# 7   Real estate, ownership of dwelling & professio...   18884241.0
# 8                                      Other services   15563222.0
# 9   Transport, storage, communication & services r...   15097286.0
# 10                                          Livestock   13068563.0
# 11                               Mining and quarrying   12454144.0
# 12                              Public administration   10424494.0
# ...

# %%
#calculationg the subsectors which are contributing 80% and above approximately
i=1;j=4
while df_C4.iloc[i:j,-1].sum()<=78:
    j=j+1

# %%
C4_Sub_Sectors= df_C4[['Item','%_of_GSDP_Contribution']].iloc[i:j].rename(columns={'Item':'C4_Sub_Sectors_contributingapprox80%'})
C4_Sub_Sectors
# Out:
#     C4_Sub_Sectors_contributingapprox80%  %_of_GSDP_Contribution
# 1      Agriculture, forestry and fishing               25.849557
# 2                                  Crops               16.312163
# 3                          Manufacturing               11.676084
# 4  Trade, repair, hotels and restaurants                9.993973
# 5                Trade & repair services                9.288358
# 6                           Construction                8.892230

# %%
#graph for the subsectors contributing approximately and more than 80%
plt.figure(figsize=(15,5))
C4_Sub_Sectors.set_index("C4_Sub_Sectors_contributingapprox80%").iloc[:-1,:]['%_of_GSDP_Contribution'].plot(kind='bar')
plt.xlabel("Subsectors(c4)")
plt.ylabel("%contribution")
plt.show()

# %% [markdown]
# How does the GDP distribution of the top states (C1) differ from the others?

# %%
print('AVG of C1 GSDP: ',round(int(df_C1.iloc[0,1])/c1.shape[0]),', Per-capita AVG of C1 :', round(c1['Per Capita GSDP (Rs.)'].mean()))
# Out:
# AVG of C1 GSDP:  25482669 , Per-capita AVG of C1 : 207730

# %%
print('AVG of C2 GSDP: ',round(int(df_C2.iloc[0,1])/c2.shape[0]),', Per-capita AVG of C2 :', round(c2['Per Capita GSDP (Rs.)'].mean()))
# Out:
# AVG of C2 GSDP:  65153384 , Per-capita AVG of C2 : 140503

# %%
print('AVG of C3 GSDP: ',round(int(df_C3.iloc[0,1])/c3.shape[0]),', Per-capita AVG of C3 :', round(c3['Per Capita GSDP (Rs.)'].mean()))
# Out:
# AVG of C3 GSDP:  25129395 , Per-capita AVG of C3 : 83836

# %%
print('AVG of C4 GSDP: ',round(int(df_C4.iloc[0,1])/c4.shape[0]),', Per-capita AVG of C4 :', round(c4['Per Capita GSDP (Rs.)'].mean()))
# Out:
# AVG of C4 GSDP:  45232911 , Per-capita AVG of C4 : 52912

# %% [markdown]
# From the above values the c1 avg GSDP is higher than c2 and c4 and almost equal to c3

# %% [markdown]
# Which sub-sectors seem to be correlated with high GDP?

# %%
df_all_states[['Item','2014-15']].groupby(by='Item').sum().sort_values(by='2014-15',ascending=False).head(10)
# Out:
#                                                          2014-15
# Item
# Gross State Domestic Product                        1.099530e+09
# TOTAL GSVA at basic prices                          1.008023e+09
# Tertiary                                            5.064437e+08
# Secondary                                           2.851220e+08
# Primary                                             2.164573e+08
# Agriculture, forestry and fishing                   1.885628e+08
# Manufacturing                                       1.699807e+08
# Real estate, ownership of dwelling & profession...  1.472633e+08
# Taxes on Products                                   1.217224e+08
# Trade, repair, hotels and restaurants               1.199639e+08

# %% [markdown]
# As per the above o/p the subsectors which are mostly corelated with GSDP are
# 1)Agriculture, forestry and fishing
# 2)Manufacturing
# 3)Real estate, ownership of dwelling & professional services
# 4)Trade, repair, hotels and restaurants

# %% [markdown]
# Which sub-sectors do the various categories need to focus on?

# %%
df_C1[['Item']].tail()
# Out:
#                                 Item
# 22                          Railways
# 23  Services incidental to transport
# 24                     Air transport
# 25                   Water transport
# 26                           Storage

# %% [markdown]
# For c1 we should focus on Railways, Services incidental to transport, Air transport, Water Transport, Storage

# %%
df_C2[['Item']].tail()
# Out:
#                                 Item
# 22  Services incidental to transport
# 23                     Air transport
# 24                           Storage
# 25                   Water transport
# 26                   Road transport*

# %% [markdown]
# For c2 we should focus on Services incidental to transport, Air transport, Storage, Water Transport, Road Transport

# %%
df_C3[['Item']].tail()
# Out:
#                                  Item
# 21   Services incidental to transport
# 22                    Water transport
# 23                            Storage
# 24  Services incidental to transport*
# 25                      Air transport

# %% [markdown]
# For c3 we should focus more on Services incidental to transport, Air transport, Storage, Water Transport, Road Transport

# %%
df_C4[['Item']].tail()
# Out:
#                                  Item
# 21   Services incidental to transport
# 22                    Water transport
# 23                            Storage
# 24  Services incidental to transport*
# 25                      Air transport

# %% [markdown]
# For c4 we should focus more on Services incidental to transport, Air transport, Storage, Water Transport, Road Transport

# %% [markdown]
# Recomondations
# 1)As per the above o/p's the transport is contributing less GDP in all the categories but transport has high demand. It menas it is running in loses. So Govt. should take care of it.
# 2)As we have calculates the avg of  percapita and gsdp. The categories where gsdp is more but percapita is less because of huge population the states. So govt. should introduce family planning programs

# %% [markdown]
# Part-2

# %%
df_drop_out=pd.read_csv('State UT-wise Average Annual Drop-Out Rate from 2012-13 to 2014-15.csv')
df_drop_out.head()
# Out:
#   Sl. No. Level of Education - State  Primary - 2012-2013  \
# 0       1              A & N Islands                 0.68
# 1       2             Andhra Pradesh                 3.18
# 2       3          Arunachal Pradesh                15.16
# 3       4                      Assam                 6.24
# 4       5                      Bihar                  NaN
#
#    Primary - 2014-2015  Primary - 2014-2015.1  Upper Primary - 2012-2013  \
# 0                 1.21                   0.51                       1.23
# 1                 4.35                   6.72                       3.36
# 2                10.89                  10.82                       7.47
# 3                 7.44                  15.36                       7.20
# 4                 2.09                    NaN                        NaN
#
#    Upper Primary - 2013-2014  Upper Primary - 2014-2015  \
# 0                       0.51                       1.69
# 1                       3.78                       5.20
# ...

# %%
df_drop_out=df_drop_out.rename(columns = {'Primary - 2014-2015':'Primary - 2013-2014','Primary - 2014-2015.1':'Primary - 2014-2015','Level of Education - State':'State'})

# %%
df_drop_out
# Out:
#       Sl. No.                 State  Primary - 2012-2013  Primary - 2013-2014  \
# 0           1         A & N Islands                 0.68                 1.21
# 1           2        Andhra Pradesh                 3.18                 4.35
# 2           3     Arunachal Pradesh                15.16                10.89
# 3           4                 Assam                 6.24                 7.44
# 4           5                 Bihar                  NaN                 2.09
# 5           6            Chandigarh                  NaN                  NaN
# 6           7           Chhatisgarh                 4.14                 1.42
# 7           8  Dadra & Nagar Haveli                  NaN                 1.57
# 8           9           Daman & Diu                  NaN                 0.85
# 9          10                 Delhi                  NaN                  NaN
# 10         11                   Goa                  NaN                 0.20
# ...

# %%
#considering only the columns primary,upper primary and secondary for year 2014-15
df_drop_out=df_drop_out[['State','Primary - 2014-2015','Upper Primary - 2014-2015','Secondary - 2014-2015']]

# %%
df_drop_out = df_drop_out.replace(['Chhatisgarh','Uttrakhand'],['Chhattisgarh','Uttarakhand'])
df_drop_out.replace(' ','_')
df_drop_out['State']=[c.replace(' ','_') for c in df_drop_out.State ]
df_drop_out
# Out:
#                    State  Primary - 2014-2015  Upper Primary - 2014-2015  \
# 0          A_&_N_Islands                 0.51                       1.69
# 1         Andhra_Pradesh                 6.72                       5.20
# 2      Arunachal_Pradesh                10.82                       6.71
# 3                  Assam                15.36                      10.51
# 4                  Bihar                  NaN                       4.08
# 5             Chandigarh                  NaN                       0.44
# 6           Chhattisgarh                 2.91                       5.85
# 7   Dadra_&_Nagar_Haveli                 1.47                       4.02
# 8            Daman_&_Diu                 1.11                       3.11
# 9                  Delhi                  NaN                       0.76
# 10                   Goa                 0.73                       0.07
# 11               Gujarat                 0.89                       6.41
# ...

# %%
#merging the frames percapita and df_drop_out
df_dropout_percap = pd.merge(df_all_states[df_all_states['Item']=='Per Capita GSDP (Rs.)'], df_drop_out, how = 'inner', on = 'State')

# %%
df_all_states[df_all_states['Item']=='Per Capita GSDP (Rs.)']
# Out:
#     S.No.                   Item   2014-15              State
# 32     17  Per Capita GSDP (Rs.)  104977.0     Andhra_Pradesh
# 65     17  Per Capita GSDP (Rs.)  112718.0  Arunachal_Pradesh
# 98     17  Per Capita GSDP (Rs.)   60621.0              Assam
# 131    17  Per Capita GSDP (Rs.)   33954.0              Bihar
# 197    17  Per Capita GSDP (Rs.)   86860.0       Chhattisgarh
# 263    17  Per Capita GSDP (Rs.)  271793.0                Goa
# 296    17  Per Capita GSDP (Rs.)  141263.0            Gujarat
# 329    17  Per Capita GSDP (Rs.)  164077.0            Haryana
# 362    17  Per Capita GSDP (Rs.)  147330.0   Himachal_Pradesh
# 395    17  Per Capita GSDP (Rs.)   62091.0          Jharkhand
# 428    17  Per Capita GSDP (Rs.)  145141.0          Karnataka
# 461    17  Per Capita GSDP (Rs.)  154778.0             Kerala
# 494    17  Per Capita GSDP (Rs.)   62989.0     Madhya_Pradesh
# 527    17  Per Capita GSDP (Rs.)  152853.0        Maharashtra
# ...

# %%
df_drop_out
# Out:
#                    State  Primary - 2014-2015  Upper Primary - 2014-2015  \
# 0          A_&_N_Islands                 0.51                       1.69
# 1         Andhra_Pradesh                 6.72                       5.20
# 2      Arunachal_Pradesh                10.82                       6.71
# 3                  Assam                15.36                      10.51
# 4                  Bihar                  NaN                       4.08
# 5             Chandigarh                  NaN                       0.44
# 6           Chhattisgarh                 2.91                       5.85
# 7   Dadra_&_Nagar_Haveli                 1.47                       4.02
# 8            Daman_&_Diu                 1.11                       3.11
# 9                  Delhi                  NaN                       0.76
# 10                   Goa                 0.73                       0.07
# 11               Gujarat                 0.89                       6.41
# ...

# %%
df_dropout_percapita=pd.merge(df_all_states[df_all_states['Item']=='Per Capita GSDP (Rs.)'],df_drop_out,how='inner',on='State')

# %%
df_dropout_percapita
# Out:
#    S.No.                   Item   2014-15              State  \
# 0     17  Per Capita GSDP (Rs.)  104977.0     Andhra_Pradesh
# 1     17  Per Capita GSDP (Rs.)  112718.0  Arunachal_Pradesh
# 2     17  Per Capita GSDP (Rs.)   60621.0              Assam
# 3     17  Per Capita GSDP (Rs.)   33954.0              Bihar
# 4     17  Per Capita GSDP (Rs.)   86860.0       Chhattisgarh
# 5     17  Per Capita GSDP (Rs.)  271793.0                Goa
# 6     17  Per Capita GSDP (Rs.)  141263.0            Gujarat
# 7     17  Per Capita GSDP (Rs.)  164077.0            Haryana
# 8     17  Per Capita GSDP (Rs.)  147330.0   Himachal_Pradesh
# 9     17  Per Capita GSDP (Rs.)   62091.0          Jharkhand
# 10    17  Per Capita GSDP (Rs.)  145141.0          Karnataka
# 11    17  Per Capita GSDP (Rs.)  154778.0             Kerala
# 12    17  Per Capita GSDP (Rs.)   62989.0     Madhya_Pradesh
# 13    17  Per Capita GSDP (Rs.)  152853.0        Maharashtra
# ...

# %%
df_dropout_percapita['total drop out in 2014-15']=df_dropout_percapita.iloc[:,-3:].sum(axis=1)
df_dropout_percapita
# Out:
#    S.No.                   Item   2014-15              State  \
# 0     17  Per Capita GSDP (Rs.)  104977.0     Andhra_Pradesh
# 1     17  Per Capita GSDP (Rs.)  112718.0  Arunachal_Pradesh
# 2     17  Per Capita GSDP (Rs.)   60621.0              Assam
# 3     17  Per Capita GSDP (Rs.)   33954.0              Bihar
# 4     17  Per Capita GSDP (Rs.)   86860.0       Chhattisgarh
# 5     17  Per Capita GSDP (Rs.)  271793.0                Goa
# 6     17  Per Capita GSDP (Rs.)  141263.0            Gujarat
# 7     17  Per Capita GSDP (Rs.)  164077.0            Haryana
# 8     17  Per Capita GSDP (Rs.)  147330.0   Himachal_Pradesh
# 9     17  Per Capita GSDP (Rs.)   62091.0          Jharkhand
# 10    17  Per Capita GSDP (Rs.)  145141.0          Karnataka
# 11    17  Per Capita GSDP (Rs.)  154778.0             Kerala
# 12    17  Per Capita GSDP (Rs.)   62989.0     Madhya_Pradesh
# 13    17  Per Capita GSDP (Rs.)  152853.0        Maharashtra
# ...

# %%
#plotting scatter plot to conduct analysis
x=df_dropout_percapita['2014-15'].values
y1=df_dropout_percapita['Primary - 2014-2015'].values
y2=df_dropout_percapita['Upper Primary - 2014-2015'].values
y3=df_dropout_percapita['Secondary - 2014-2015'].values
y4=df_dropout_percapita['total drop out in 2014-15'].values

# %%
#scatter plot for GSDP and primary
plt.figure(figsize=[5,4])
plt.xlabel('Per Capita GSDP (Rs.)')
plt.ylabel('Primary - 2014-2015 dropouts')
plt.scatter(x,y1)
plt.show()

# %%
#scatter plot for GSDP and Upper-Primary
plt.figure(figsize=[5,4])
plt.xlabel('Per Capita GSDP (Rs.)')
plt.ylabel('Upper-Primary - 2014-2015 dropouts')
plt.scatter(x,y2)
plt.show()

# %%
#scatter plot for GSDP and Secondary
plt.figure(figsize=[5,4])
plt.xlabel('Per Capita GSDP (Rs.)')
plt.ylabel('Secondary - 2014-2015 dropouts')
plt.scatter(x,y3)
plt.show()

# %%
#scatter plot for GSDP and total dropouts in 2014-15
plt.figure(figsize=[5,4])
plt.xlabel('Per Capita GSDP (Rs.)')
plt.ylabel('total dropouts in 2014-15')
plt.scatter(x,y4)
plt.show()

# %% [markdown]
# From the above graphs we can see that the drop-out rate decreases as the percapita GSDP increases
